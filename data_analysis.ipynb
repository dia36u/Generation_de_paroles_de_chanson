# %%
# importing the dataset
import pandas as pd
import numpy
from sklearn import preprocessing

# %%
df_artists = pd.read_csv(r'dataset\artists-data.csv')
df_lyrics = pd.read_csv(r'dataset\lyrics-data.csv')

# %%
df=pd.merge(df_artists,df_lyrics,left_on='Link',right_on='ALink')
df_genre=df['Genres'].str.split(';',expand=True)
for colums in df_genre:
    df_genre[colums] = df_genre[colums].str.strip()
df=pd.merge(df,df_genre,left_on=df.index,right_on=df_genre.index)
df.rename(columns={0: "Genre 1", 1: "Genre 2",2: "Genre 3", 3: "Genre 4"}, inplace=True)
df.drop(['SLink', 'key_0','Genres','Link','ALink'], axis=1,inplace=True)

# %%
df[['language']].value_counts().head(5)
# Out:
# language
# en          191387
# pt          156941
# es            9916
# rw            1679
# it            1426
# dtype: int64

# %%
df
# Out:
#                Artist  Songs  Popularity  \
# 0       Ivete Sangalo  313.0         4.4
# 1       Ivete Sangalo  313.0         4.4
# 2       Ivete Sangalo  313.0         4.4
# 3       Ivete Sangalo  313.0         4.4
# 4       Ivete Sangalo  313.0         4.4
# ...               ...    ...         ...
# 378983   Johnny Clegg   34.0         0.0
# 378984   Johnny Clegg   34.0         0.0
# 378985   Johnny Clegg   34.0         0.0
# 378986   Johnny Clegg   34.0         0.0
# 378987   Johnny Clegg   34.0         0.0
#
#                                                 SName  \
# 0                                               Arerê
# 1                     Se Eu Não Te Amasse Tanto Assim
# 2                                         Céu da Boca
# 3                               Quando A Chuva Passar
# 4                                        Sorte Grande
# ...                                               ...
# 378983                                    The Waiting
# 378984                          Too Early For The Sky
# 378985  Warsaw 1943 (I Never Betrayed The Revolution)
# 378986                     When The System Has Fallen
# 378987                            Woman Be My Country
#
#                                                     Lyric language  \
# 0       Tudo o que eu quero nessa vida,\nToda vida, é\...       pt
# 1       Meu coração\nSem direção\nVoando só por voar\n...       pt
# 2       É de babaixá!\nÉ de balacubaca!\nÉ de babaixá!...       pt
# 3       Quando a chuva passar\n\nPra quê falar\nSe voc...       pt
# 4       A minha sorte grande foi você cair do céu\nMin...       pt
# ...                                                   ...      ...
# 378983  Chorus\nHere we stand waiting on the plain\nDa...       en
# 378984  I nearly disappeared into the mouth of a croco...       en
# 378985  Amambuka, amambuka azothengisa izwe lakithi, i...       en
# 378986  Sweat in the heat for days on end\nwaiting for...       en
# 378987  Here we stand on the edge of the day\nFaces me...       en
#
#             Genre 1           Genre 2    Genre 3 Genre 4
# 0               Pop               Axé  Romântico    None
# 1               Pop               Axé  Romântico    None
# 2               Pop               Axé  Romântico    None
# 3               Pop               Axé  Romântico    None
# 4               Pop               Axé  Romântico    None
# ...             ...               ...        ...     ...
# 378983  World Music  Gospel/Religioso       None    None
# 378984  World Music  Gospel/Religioso       None    None
# 378985  World Music  Gospel/Religioso       None    None
# 378986  World Music  Gospel/Religioso       None    None
# 378987  World Music  Gospel/Religioso       None    None
#
# [378988 rows x 10 columns]

# %%
from collections import Counter

def genre_by_language(language, df=df):
    genre={}
    df_lang = df[df['language']==language]
    dict_0 = df_lang["Genre 1"].value_counts().to_dict()
    dict_1 = df_lang["Genre 2"].value_counts().to_dict()
    dict_2 = df_lang["Genre 3"].value_counts().to_dict()
    dict_3 = df_lang["Genre 4"].value_counts().to_dict()
    genre = Counter(dict_0) + Counter(dict_1) + Counter(dict_2) + Counter(dict_3)
    return(genre)

# %%
genre=genre_by_language("en")
sorted(genre.items(), key=lambda t: t[1], reverse=True)
# Out:
# [('Rock', 63717),
#  ('Pop', 33571),
#  ('Pop/Rock', 26360),
#  ('Heavy Metal', 21759),
#  ('Hip Hop', 20902),
#  ('Indie', 20134),
#  ('Romântico', 17947),
#  ('Hard Rock', 17250),
#  ('Rap', 17114),
#  ('R&B', 15581),
#  ('Rock Alternativo', 13061),
#  ('Black Music', 13024),
#  ('Dance', 11895),
#  ('Folk', 11124),
#  ('Country', 10630),
#  ('Punk Rock', 9215),
#  ('Soul Music', 8131),
#  ('Electronica', 7799),
#  ('Gospel/Religioso', 7337),
#  ('Hardcore', 7082),
#  ('Trilha Sonora', 6213),
#  ('Blues', 6094),
#  ('Gótico', 4984),
#  ('Soft Rock', 4483),
#  ('Progressivo', 4365),
#  ('Jazz', 4343),
#  ('Tecnopop', 3873),
#  ('Pós-Punk', 3274),
#  ('Reggae', 3207),
#  ('Rockabilly', 3100),
#  ('New Wave', 3075),
#  ('Pop/Punk', 3039),
#  ('Disco', 2890),
#  ('Grunge', 2752),
#  ('Funk', 2454),
#  ('Psicodelia', 2258),
#  ('Clássico', 2170),
#  ('Instrumental', 1909),
#  ('Surf Music', 1901),
#  ('House', 1785),
#  ('Emocore', 1689),
#  ('Axé', 1620),
#  ('Classic Rock', 1533),
#  ('COLETÂNEA', 1392),
#  ('J-Pop/J-Rock', 1230),
#  ('Infantil', 1220),
#  ('Trip-Hop', 1203),
#  ('Ska', 1200),
#  ('New Age', 1117),
#  ('Industrial', 1004),
#  ('Chillout', 974),
#  ('Piano Rock', 965),
#  ('Power-Pop', 917),
#  ('MPB', 768),
#  ('World Music', 680),
#  ('Trance', 659),
#  ('K-Pop/K-Rock', 632),
#  ('Funk Carioca', 585),
#  ('Metal', 432),
#  ('Bossa Nova', 375),
#  ('Velha Guarda', 226),
#  ('Sertanejo', 198),
#  ('Tropical House', 168),
#  ('Jovem Guarda', 150),
#  ('Post-Rock', 136),
#  ('Trap', 116),
#  ('Lo-fi', 86),
#  ('Samba', 82),
#  ('Fado', 41),
#  ('Reggaeton', 35),
#  ('Pagode', 29),
#  ('Forró', 18),
#  ('Kizomba', 7),
#  ('Electro Swing', 6),
#  ('Regional', 2)]

# %%
first_genre=genre="Rock"
first_lg="en"

# %%
df=df.iloc[df.index[(df['Genre 1']==first_genre) | (df['Genre 2']==first_genre) | (df['Genre 3']==first_genre) | (df['Genre 4']==first_genre)].tolist()]
df=df[df['language']==first_lg]
df.drop(['language', 'Genre 1','Genre 2','Genre 3','Genre 4'], axis=1,inplace=True)
df
# Out:
#                Artist  Songs  Popularity  \
# 16609   Elvis Presley  759.0        23.1
# 16610   Elvis Presley  759.0        23.1
# 16611   Elvis Presley  759.0        23.1
# 16612   Elvis Presley  759.0        23.1
# 16613   Elvis Presley  759.0        23.1
# ...               ...    ...         ...
# 375531   Club Penguin   11.0         0.0
# 375532   Club Penguin   11.0         0.0
# 375533   Club Penguin   11.0         0.0
# 375534   Club Penguin   11.0         0.0
# 375535   Club Penguin   11.0         0.0
#
#                                        SName  \
# 16609             Can't Help Falling In Love
# 16610                       Suspicious Minds
# 16611                      Always On My Mind
# 16612                         Love Me Tender
# 16613                                 My Way
# ...                                      ...
# 375531                      Party in my Iggy
# 375532                  The Party Starts Now
# 375533      We Are the Penguins - Dj Cadence
# 375534  You Gotta Have Wigman (Puffle Party)
# 375535                       You've Got This
#
#                                                     Lyric
# 16609   Wise men say, only fools rush in\nBut I can't ...
# 16610   We're caught in a trap\nI can't walk out\nBeca...
# 16611   Maybe I didn't treat you,\nQuite as good as I ...
# 16612   Love me tender, love me sweet,\nNever let me g...
# 16613   And now the end is near\nAnd so I face the fin...
# ...                                                   ...
# 375531  I wonder what's that funky sound\nfrom around ...
# 375532  Get up Party Penguins come on haven't you hear...
# 375533  Check one\nTurn the volume up\nAnd join the cl...
# 375534  Puffle party, party, party, party, party\n\nWe...
# 375535  All you need is a beat\nThat could make the gr...
#
# [63717 rows x 5 columns]

# %%
df2 = df[df.Popularity > 10]
df2
# Out:
#                Artist  Songs  Popularity                       SName  \
# 16609   Elvis Presley  759.0        23.1  Can't Help Falling In Love
# 16610   Elvis Presley  759.0        23.1            Suspicious Minds
# 16611   Elvis Presley  759.0        23.1           Always On My Mind
# 16612   Elvis Presley  759.0        23.1              Love Me Tender
# 16613   Elvis Presley  759.0        23.1                      My Way
# ...               ...    ...         ...                         ...
# 313529  4 Non Blondes   15.0        10.1          Misty Mountain Hop
# 313530  4 Non Blondes   15.0        10.1      Morphine And Chocolate
# 313531  4 Non Blondes   15.0        10.1          No Place Like Home
# 313532  4 Non Blondes   15.0        10.1              Old Mr. Heffer
# 313533  4 Non Blondes   15.0        10.1                    Superfly
#
#                                                     Lyric
# 16609   Wise men say, only fools rush in\nBut I can't ...
# 16610   We're caught in a trap\nI can't walk out\nBeca...
# 16611   Maybe I didn't treat you,\nQuite as good as I ...
# 16612   Love me tender, love me sweet,\nNever let me g...
# 16613   And now the end is near\nAnd so I face the fin...
# ...                                                   ...
# 313529  Walkin' in the park just the other day, baby,\...
# 313530  Substitute my gloom with happiness\nSubstitute...
# 313531  When I wake up in my house\nI get dressed then...
# 313532  Stumbled my way on the darkest afternoon\nI go...
# 313533  Here i am and i'm waitin' on a chance to make ...
#
# [9195 rows x 5 columns]

# %%
df3=df2.drop_duplicates(subset='Artist')
df4=df2.drop_duplicates(subset='Artist',keep='last')
df3=pd.concat([df3,df4])

# %%
df3
# Out:
#                               Artist  Songs  Popularity  \
# 16609                  Elvis Presley  759.0        23.1
# 17590                 Rolling Stones  438.0        12.8
# 27576                          AC/DC  204.0        19.2
# 28420                     Pink Floyd  208.0        42.6
# 31645   Creedence Clearwater Revival   67.0        13.7
# ...                              ...    ...         ...
# 287715         Red Hot Chili Peppers  267.0        41.4
# 312737                   John Lennon  135.0        43.8
# 313008                   Bryan Adams  271.0        20.8
# 313461                   Rod Stewart  453.0        16.2
# 313533                 4 Non Blondes   15.0        10.1
#
#                                           SName  \
# 16609                Can't Help Falling In Love
# 17590                    Sympathy For The Devil
# 27576                             Back In Black
# 28420   Another Brick In The Wall (part 1,2, 3)
# 31645              Have You Ever Seen The Rain?
# ...                                         ...
# 287715                           Your Eyes Girl
# 312737                               Your Hands
# 313008                               Young Lust
# 313461                                Your Song
# 313533                                 Superfly
#
#                                                     Lyric
# 16609   Wise men say, only fools rush in\nBut I can't ...
# 17590   Please allow me to introduce myself\nI'm a man...
# 27576   Back in black, I hit the sack,\nI've been too ...
# 28420   Parte1\nDaddy's flown across the ocean\nLeavin...
# 31645   Someone told me long ago\nThere's a calm befor...
# ...                                                   ...
# 287715  I'm afraid that i'm never afraid\nI've got com...
# 312737  Anatano te\nKonnani kireina\nAnatano te\nYumen...
# 313008  I am just a new boy\nStranger in this town\nWh...
# 313461  It's a little bit funny this feeling inside\nI...
# 313533  Here i am and i'm waitin' on a chance to make ...
#
# [90 rows x 5 columns]

# %%
df=df3.drop(['Artist', 'Songs','Popularity','SName'], axis=1)

# %%
df
# Out:
#                                                     Lyric
# 16609   Wise men say, only fools rush in\nBut I can't ...
# 17590   Please allow me to introduce myself\nI'm a man...
# 27576   Back in black, I hit the sack,\nI've been too ...
# 28420   Parte1\nDaddy's flown across the ocean\nLeavin...
# 31645   Someone told me long ago\nThere's a calm befor...
# ...                                                   ...
# 287715  I'm afraid that i'm never afraid\nI've got com...
# 312737  Anatano te\nKonnani kireina\nAnatano te\nYumen...
# 313008  I am just a new boy\nStranger in this town\nWh...
# 313461  It's a little bit funny this feeling inside\nI...
# 313533  Here i am and i'm waitin' on a chance to make ...
#
# [90 rows x 1 columns]

# %%
df.to_csv('dataset\lyrics_clean.csv',index=False)

# %%
import sqlite3

conn = sqlite3.connect('database.db')
c = conn.cursor()
c.execute('CREATE TABLE IF NOT EXISTS lyrics (lyrics)')
conn.commit()

df.to_sql("lyrics", conn, if_exists='replace', index=False)
# Out:
# 90
